# %% [markdown]
# # RAG System Experiments
#
# This notebook contains experiments for evaluating and tuning the RAG system.

# %%
import sys

sys.path.append("..")

from rag_system.core.chunking import SemanticChunker
from rag_system.core.retrieval import ReciprocalRankFusion
from rag_system.config import settings

# %% [markdown]
# ## Experiment 1: Chunking Strategy Evaluation
#
# Compare different chunking strategies and sizes.

# %%
# Test different chunk sizes
chunk_sizes = [100, 200, 300, 500]

sample_text = """Your sample document text here..."""

for size in chunk_sizes:
    chunker = SemanticChunker(chunk_size=size, overlap=50)
    chunks = chunker.chunk_document(sample_text, {"source": "test"})
    print(f"Chunk size {size}: {len(chunks)} chunks created")

# %% [markdown]
# ## Experiment 2: Retrieval Quality
#
# Evaluate retrieval accuracy with different methods.

# %%
# Implement retrieval quality evaluation
# Compare dense vs sparse vs hybrid retrieval

# %% [markdown]
# ## Experiment 3: Cache Performance
#
# Analyze cache hit rates and similarity thresholds.

# %%
# Test different similarity thresholds
thresholds = [0.90, 0.92, 0.95, 0.97, 0.99]

# Evaluate cache hit rate vs precision trade-off
